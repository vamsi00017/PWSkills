# %% [markdown]
# # **Feature_Engineering**

# %% [markdown]
# 1) What is a parameter?
#
# Ans: Parameters are the variables which are responsible for the model to predict or generate the ouput which are produced based on the trained data.

# %% [markdown]
# 2) What is correlation? What does negative correlation mean?
#
# Ans: Correlation is uesd to find the relationship between two variables.
# Negative Correlation mean means when one variable increases the other variable decreases.

# %% [markdown]
# 3)Define Machine Learning. What are the main components in Machine Learning?
#
# Ans: Machine Learning is a subset of Artificial intelligence which predicts the output by analysining the patterns in the data using stastics and other mathematical operations. The important components are Model,Data,Algorithms.

# %% [markdown]
# 4)How does loss value help in determining whether the model is good or not?
#
# Ans: Loss Value help to determine whether the model is good or not by comparing the predicted output of the model and the original output in the data which will help to find the accuracy of the model.

# %% [markdown]
# 5)What are continuous and categorical variables?
#
# Ans: Continuos variables are which having the range of the numbers for example Salary 50000- 60000 which means that the variable may be in the middle of that range. Categorical Variable are like specific example Yes or No, Fail or Success, Profit or Loss .

# %% [markdown]
# 6)How do we handle categorical variables in Machine Learning? What are the common techniques?
#
# Ans: Most of the models are not suitable for categorical variables to avoid this convert into the numerical values which model will understand. The types of techniques are 1)Nominal 2)label & ordinal 3)Target guided ordinal encoding .

# %% [markdown]
# 7)What do you mean by training and testing a dataset?
#
# Ans: The collected data is divided into two parts in a ratio which is training and testing where training data is used to train the model which will finds the patterns and testing data is used to predict the output from the testing data inputs .

# %% [markdown]
# 8)What is sklearn.preprocessing?
#
# Ans: It is library which contains all the functions which are related to the data preprocessing where the data will be cleaned and transformed before training the model .

# %% [markdown]
# 9)What is a Test set?
#
# Ans: it is a portion of data in the dataset where it is not used to train the model and later it is used to compare the output generated by the model to find the accuracy .

# %% [markdown]
# 10)How do we split data for model fitting (training and testing) in Python?
# How do you approach a Machine Learning problem?
#
# Ans: Spliting  of the data is possible by using Sklearn library where we import train_test_split module.
# x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
# in the above line we define the test size as 0.2 where 80% data is used for training and 20% of data is used for testing and the random_state selects the data in the same way as it selected in many times.

# %% [markdown]
# 11)Why do we have to perform EDA before fitting a model to the data?
#
# Ans: EDA is performed to fit the model with our data. To perform this first step is we need to do data analysis and next it is data cleaning and next model selection which model gives good accuracy.

# %% [markdown]
# 12) What is correlation?
#
# Ans:Correlation is uesd to find the relationship between two variables.Where if one variable increase the other variable will increase or decrease.

# %% [markdown]
# 13)What does negative correlation mean?
#
# Ans:Negative Correlation mean means when one variable increases the other variable decreases.

# %% [markdown]
# 14)How can you find correlation between variables in Python?
#
# Ans: we find the correlation by using corr() function where it dispays the table with columns names which have the ratios by which column ratio the other coulumn ration will increase.we can also find the correlation by using heat map also.

# %% [markdown]
# 15)What is causation? Explain difference between correlation and causation with an example?
#
# Ans: Causation is the cause and effect which means if one change in variable causes the change in the other variable. If the first varibale is not changed then the second is not impacted. where in the correlation if one is changed then other will change.

# %% [markdown]
# 16)What is an Optimizer? What are different types of optimizers? Explain each with an example.
#
# Ans: it is a algorithm which is used to adjust the parameters for increasing the model accuracy.

# %% [markdown]
# 17)What is sklearn.linear_model ?
#
# Ans: it is the submodule of sklearn where it has the collection of linear regression models.It is mainly used when we want to predict the target variable based the linear input data points.

# %% [markdown]
# 18)What does model.fit() do? What arguments must be given?
#
# Ans: model.fit is used to train the model with the parameters in the data tben the model will find the patterns in the given data. Model.Fit takes the x (feature data) and y (target data) .

# %% [markdown]
# 19)What does model.predict() do? What arguments must be given?
#
# Ans:This is used after the model is trained. model.predict is used to predict the output from the trained model with the input parameters and get the target variables(output ) from the model.

# %% [markdown]
# 20)What are continuous and categorical variables?
#
# Ans:Continuos variables are which having the range of the numbers for example Salary 50000- 60000 which means that the variable may be in the middle of that range. Categorical Variable are like specific example Yes or No, Fail or Success, Profit or Loss .

# %% [markdown]
# 21)What is feature scaling? How does it help in Machine Learning?
#
# Ans: Feature scaling is the process of transforming numerical feature of data to a normal scale.

# %% [markdown]
# 22)How do we perform scaling in Python?
#
# Ans:To perform scaling in python first we need to select the type of scaling and then we need to call the model and fit and transform then we can print the data which is trained.

# %% [markdown]
# 23)What is sklearn.preprocessing?
#
# Ans:It is library which contains all the functions which are related to the data preprocessing where the data will be cleaned and transformed before training the model .

# %% [markdown]
# 24)How do we split data for model fitting (training and testing) in Python?
#
# Ans:Spliting of the data is possible by using Sklearn library where we import train_test_split module. x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42) in the above line we define the test size as 0.2 where 80% data is used for training and 20% of data is used for testing and the random_state selects the data in the same way as it selected in many times.

# %% [markdown]
# 25)Explain data encoding?
#
# Ans: it is mainly used during preprocessing of data. Ml models require numerical data to train so when the data is in categorical then we use data encoding. where it converts the categorical data into labels so that it will make easy for the model to understand the data.
